# %% [markdown]
# # COMS 4111 project 1 part3
#
# Teammates:
# - Jace Yang (uni: jy3174)
# - Binghong Yu (uni: by2325)
#
# The UNI used to create the schema on the course database server: by2325

# %% [markdown]
# ## 0. Environment Setup

# %%
# !pip3 install sqlalchemy # ORM for databases
# !pip3 install ipython-sql
# Out:
# Requirement already satisfied: sqlalchemy in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (1.4.35)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from sqlalchemy) (1.1.2)
# Requirement already satisfied: ipython-sql in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (0.4.0)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython>=1.0 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (7.31.1)
# Requirement already satisfied: sqlparse in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.4.2)
# Requirement already satisfied: prettytable<1 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (0.7.2)
# Requirement already satisfied: six in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: sqlalchemy>=0.6.7 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython-sql) (1.4.35)
# Requirement already satisfied: appnope in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: pygments in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (2.11.2)
# Requirement already satisfied: pickleshare in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.1.2)
# Requirement already satisfied: decorator in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (3.0.20)
# Requirement already satisfied: backcall in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (4.8.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (58.0.4)
# Requirement already satisfied: traitlets>=4.2 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from ipython>=1.0->ipython-sql) (5.1.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=1.0->ipython-sql) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (from sqlalchemy>=0.6.7->ipython-sql) (1.1.2)

# %%
# %load_ext sql

# %%
# !pip install psycopg2-binary
# Out:
# Requirement already satisfied: psycopg2-binary in /Users/binghongyu/opt/anaconda3/lib/python3.8/site-packages (2.9.3)

# %%
from sqlalchemy import *
SUBMIT = True

if not SUBMIT:
    DATABASEURI = "postgresql://jy3174:JaceYJH@w4111.cisxo09blonu.us-east-1.rds.amazonaws.com/proj1part2"
    # %sql postgresql://jy3174:JaceYJH@w4111.cisxo09blonu.us-east-1.rds.amazonaws.com/proj1part2
else:
    DATABASEURI = "postgresql://by2325:0316@w4111.cisxo09blonu.us-east-1.rds.amazonaws.com/proj1part2"
    # %sql postgresql://by2325:0316@w4111.cisxo09blonu.us-east-1.rds.amazonaws.com/proj1part2
engine = create_engine(DATABASEURI)

# Here we create a test table and insert some values in it
engine.execute("""DROP TABLE IF EXISTS test;""")
engine.execute("""CREATE TABLE IF NOT EXISTS test (
  id serial,
  name text
);""")
engine.execute("""INSERT INTO test(name) VALUES ('grace hopper'), ('alan turing'), ('ada lovelace');""")
# Out:
# (psycopg2.OperationalError) connection to server at "w4111.cisxo09blonu.us-east-1.rds.amazonaws.com" (3.216.102.114), port 5432 failed: FATAL:  remaining connection slots are reserved for non-replication superuser and rds_superuser connections
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: connection to server at "w4111.cisxo09blonu.us-east-1.rds.amazonaws.com" (3.216.102.114), port 5432 failed: FATAL:  remaining connection slots are reserved for non-replication superuser and rds_superuser connections
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/q4/lygmy6kj77z_5zc1r5s6c0t80000gn/T/ipykernel_80069/1604944776.py in <module>
#      11
#      12 # Here we create a test table and insert some values in it
# ---> 13 engine.execute("""DROP TABLE IF EXISTS test;""")
#      14 engine.execute("""CREATE TABLE IF NOT EXISTS test (
#      15   id serial,
#
# <string> in execute(self, statement, *multiparams, **params)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     399         if not skip_warning:
#     400             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401         return fn(*args, **kwargs)
#     402
#     403     doc = func.__doc__ is not None and func.__doc__ or ""
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3173
#    3174         """
# -> 3175         connection = self.connect(close_with_result=True)
#    3176         return connection.execute(statement, *multiparams, **params)
#    3177
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3232         """
#    3233
# -> 3234         return self._connection_cls(self, close_with_result=close_with_result)
#    3235
#    3236     @util.deprecated(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3311
#    3312         """
# -> 3313         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3314
#    3315
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3281         except dialect.dbapi.Error as e:
#    3282             if connection is None:
# -> 3283                 Connection._handle_dbapi_exception_noconnection(
#    3284                     e, dialect, self
#    3285                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2115             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2116         elif should_wrap:
# -> 2117             util.raise_(
#    2118                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2119             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3278         dialect = self.dialect
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#    3282             if connection is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     664         except Exception as e:
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#     668             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     595     def connect(self, *cargs, **cparams):
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#     599     def create_connect_args(self, url):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "w4111.cisxo09blonu.us-east-1.rds.amazonaws.com" (3.216.102.114), port 5432 failed: FATAL:  remaining connection slots are reserved for non-replication superuser and rds_superuser connections
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ## Testing

# %%
# %%sql
# SELECT business_id, array_agg(name) as category_names
# FROM Business_tagged_Category
# group by business_id
# limit 10

# %%
# %%sql
# SELECT business_id, string_agg(name,', ') as category_names
# FROM Business_tagged_Category
# group by business_id
# limit 10

# %%
# %%sql
# SELECT *
# FROM business_wide
# JOIN (SELECT business_id, array_agg(name) as category_names
# FROM Business_tagged_Category
# GROUP BY business_id) as tmp
# using(business_id)
# limit 10
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
#
#
# SELECT *
# FROM biz_with_stars
# JOIN (SELECT business_id, string_agg(name,', ') as category_names
# FROM Business_tagged_Category
# GROUP BY business_id) as tmp
# using(business_id)
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
def get_password(user_id):
    result = %sql SELECT * FROM USERS WHERE user_id = :user_id
    return result

# %% [markdown]
# ## Prototype code

# %%
# %%sql
#
# SELECT *
# FROM Users_follow_Users LIMIT 5
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
get_password('0IgHCokoqcQETC5XBxxyPQ')
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
#
# SELECT *
# FROM Users
# LIMIT 5
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
#
# SELECT COUNT(DISTINCT fan_user_id) AS fans
# FROM Users_follow_Users
# WHERE follwee_user_id = 'sadf阿斯顿发生'
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
#
# WITH one_user_collections AS(
#     SELECT user_id AS collection_owner_id, collection_id
#     FROM Collection_of_User
#     WHERE user_id = '9Xmw_WcUCShPD0qGO1UD7w')
# SELECT collection_id, COUNT(CASE WHEN business_id = 'BXPyrf12pvtP6fXNvYZUeg' THEN 1 ELSE NULL END) AS biz_in
# FROM one_user_collections
# JOIN Collection_contain_Business USING(collection_owner_id, collection_id)
# GROUP BY collection_id
# ORDER BY collection_id
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
STARTS_OPTIONS = [(str(i/2), str(i/2) + ' stars' if i != 2 else str(i/2) + ' star') for i in list(range(11))]
STARTS_OPTIONS
# Out:
# [('0.0', '0.0 stars'),
#  ('0.5', '0.5 stars'),
#  ('1.0', '1.0 star'),
#  ('1.5', '1.5 stars'),
#  ('2.0', '2.0 stars'),
#  ('2.5', '2.5 stars'),
#  ('3.0', '3.0 stars'),
#  ('3.5', '3.5 stars'),
#  ('4.0', '4.0 stars'),
#  ('4.5', '4.5 stars'),
#  ('5.0', '5.0 stars')]

# %%
# %%sql
# SELECT *
# FROM Review_of_Business
# WHERE business_id = ''
# LIMIT 10
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
# SELECT *
# FROM Users_write_Review
# LIMIT 10
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
# SELECT collection_id, COUNT(CASE WHEN business_id = 'BXPyrf12pvtP6fXNvYZUeg' THEN 1 ELSE 0 END)
# FROM one_user_collections
# JOIN Collection_contain_Business USING(collection_owner_id, collection_id)
# GROUP BY collection_id
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
# SELECT *
# FROM Users_write_Review
# WHERE user_id = 'n5pZpeQE-ASr1aQx81mKVQ'
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
#
# SELECT * FROM Business
# LIMIT 5
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
# UPDATE Review_of_Business
# SET useful = useful + 1
# WHERE review_id = 100231
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
# %%sql
# SELECT *
# FROM Users_write_Review
# WHERE user_id = 'n5pZpeQE-ASr1aQx81mKVQ'
# LIMIT 5
# Out:
# Environment variable $DATABASE_URL not set, and no connect string given.
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %%
DB_USER = "jy3174"
DB_PASSWORD = "JaceYJH"
DB_SERVER = "w4111.cisxo09blonu.us-east-1.rds.amazonaws.com"
#DATABASEURI = "postgresql://"+DB_USER+":"+DB_PASSWORD+"@"+DB_SERVER+"/w4111"
DATABASEURI = "postgresql://"+DB_USER+":"+DB_PASSWORD+"@"+DB_SERVER+"/proj1part2"
engine = create_engine(DATABASEURI)
con = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: connection to server at "w4111.cisxo09blonu.us-east-1.rds.amazonaws.com" (3.216.102.114), port 5432 failed: FATAL:  remaining connection slots are reserved for non-replication superuser and rds_superuser connections
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# /var/folders/q4/lygmy6kj77z_5zc1r5s6c0t80000gn/T/ipykernel_80069/4040364368.py in <module>
#       5 DATABASEURI = "postgresql://"+DB_USER+":"+DB_PASSWORD+"@"+DB_SERVER+"/proj1part2"
#       6 engine = create_engine(DATABASEURI)
# ----> 7 con = engine.connect()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3232         """
#    3233
# -> 3234         return self._connection_cls(self, close_with_result=close_with_result)
#    3235
#    3236     @util.deprecated(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3311
#    3312         """
# -> 3313         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3314
#    3315
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3281         except dialect.dbapi.Error as e:
#    3282             if connection is None:
# -> 3283                 Connection._handle_dbapi_exception_noconnection(
#    3284                     e, dialect, self
#    3285                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2115             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2116         elif should_wrap:
# -> 2117             util.raise_(
#    2118                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2119             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3278         dialect = self.dialect
#    3279         try:
# -> 3280             return fn()
#    3281         except dialect.dbapi.Error as e:
#    3282             if connection is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     664         except Exception as e:
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#     668             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     595     def connect(self, *cargs, **cparams):
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#     599     def create_connect_args(self, url):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "w4111.cisxo09blonu.us-east-1.rds.amazonaws.com" (3.216.102.114), port 5432 failed: FATAL:  remaining connection slots are reserved for non-replication superuser and rds_superuser connections
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
import secrets
def add_user_to_db(email, name, password, user_id=None, yealping_since=None):
    if not user_id:
        user_id = secrets.token_hex(11)
    if not yealping_since:
        yealping_since = date.today().strftime("%Y-%m-%d")

    con.execute('''
        INSERT INTO Users (user_id, email, name, password, yealping_since) 
        VALUES (%s, %s, %s, %s, %s)''',
    (user_id, email, name, password, yealping_since))

# %%
add_user_to_db('123@gmail.com', 'Jace', '12345678')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/q4/lygmy6kj77z_5zc1r5s6c0t80000gn/T/ipykernel_80069/1899881071.py in <module>
# ----> 1 add_user_to_db('123@gmail.com', 'Jace', '12345678')
#
# /var/folders/q4/lygmy6kj77z_5zc1r5s6c0t80000gn/T/ipykernel_80069/1353316668.py in add_user_to_db(email, name, password, user_id, yealping_since)
#       4         user_id = secrets.token_hex(11)
#       5     if not yealping_since:
# ----> 6         yealping_since = date.today().strftime("%Y-%m-%d")
#       7
#       8     con.execute('''
#
# NameError: name 'date' is not defined

# %%
# %%sql
# WITH one_collection AS(
#     SELECT user_id AS collection_owner_id, collection_id
#     FROM Collection_of_User
#     WHERE user_id = '9Xmw_WcUCShPD0qGO1UD7w' AND collection_id = 1),
#
# one_collection_n_fan AS(
#     SELECT a.collection_owner_id AS collection_owner_id,
#            a.collection_id AS collection_id,
#            COUNT(DISTINCT fan_user_id) AS n_fans
#     FROM one_collection a LEFT JOIN Users_follow_Collection b ON
#         a.collection_owner_id = b.followee_user_id AND
#         a.collection_id = b.collection_id
#     GROUP BY a.collection_owner_id, a.collection_id
#
# )
#
# SELECT CONCAT('Collection NO.', collection_id, ' with ', COUNT(business_id), ' restaurants') AS collection_name, n_fans
# FROM one_collection_n_fan
#     LEFT JOIN Collection_contain_Business USING(collection_owner_id, collection_id)
# GROUP BY collection_owner_id, collection_id, n_fans
# Out:
#  * postgresql://jy3174:***@w4111.cisxo09blonu.us-east-1.rds.amazonaws.com/proj1part2
# 1 rows affected.
# [('Collection NO.1 with 5 restaurants', 8)]

# %%
# %%sql
# SELECT * FROM
# Users_follow_Collection
# LIMIT 5
# Out:
#  * postgresql://jy3174:***@w4111.cisxo09blonu.us-east-1.rds.amazonaws.com/proj1part2
# 5 rows affected.
# [('STO9KprPS0pZVO75VX_bvA', 'hnJX1DJ4BxCo20K-Q7DL7Q', 4),
#  ('STO9KprPS0pZVO75VX_bvA', 'cekNA8jVlv7yODhH6dLp0A', 3),
#  ('BQX9nEi5q8KSqiiMs921Iw', 'MY4fXD72l2cmbut2mQfgng', 6),
#  ('ZuyxS4F2zdBMjghIj1auAA', 'MY4fXD72l2cmbut2mQfgng', 7),
#  ('ZuyxS4F2zdBMjghIj1auAA', 'kKjemwH3DHCRW2flG2eGdg', 1)]

# %%
# %%sql
# With bizs_id_in_one_state as(
#     SELECT *
#     FROM Business
#     where state = 'PA'
# ),
# bizs_in_one_state as(
#     SELECT business_id, round(AVG(stars), 2) AS average_stars
#     FROM Review_of_Business JOIN bizs_id_in_one_state USING(business_id)
#     WHERE detailed_review IS NOT NULL
#     GROUP BY business_id)
# SELECT *
# FROM bizs_in_one_state RIGHT JOIN bizs_id_in_one_state USING(business_id)
# Out:
#  * postgresql://by2325:***@w4111.cisxo09blonu.us-east-1.rds.amazonaws.com/proj1part2
# 207 rows affected.
# [('jcmJVfvefkVnx6h_idOazA', Decimal('4.00'), "Connie's Ric Rac", '1132 S 9th St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), False, False),
#  ('B_CXPcgf8QzKbNCdK5oLPw', Decimal('5.00'), 'Ocean City Coffee', '34 W State St', 'Media', 'PA', '19063', Decimal('40'), Decimal('-75'), True, False),
#  ('h8bA4cN4_F_swep3yMeOfA', Decimal('4.09'), "Gramm's Kitchen", '557 E Gay St', 'West Chester', 'PA', '19380', Decimal('40'), Decimal('-76'), True, True),
#  ('_f6Nt2ANNIkemPuA_QnsmA', Decimal('4.50'), 'PrimoHoagies', '2417 Welsh Rd, Ste 12', 'Philadelphia', 'PA', '19114', Decimal('40'), Decimal('-75'), True, True),
#  ('y1OnXk_6L74oM4ehHqVYgw', Decimal('4.50'), 'Pin Wei', '968 County Line Rd', 'Bryn Mawr', 'PA', '19010', Decimal('40'), Decimal('-75'), True, True),
#  ('l7e7-RIhNx-kiZ9hQo6iLg', Decimal('4.55'), "Esposito's Meats", '1001 S 9th St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), True, True),
#  ('BtxUZn4d7yxsHwdlRq1dkw', Decimal('4.67'), 'Mount Airy Tap Room', '300 W Mt Pleasant Ave', 'Philadelphia', 'PA', '19119', Decimal('40'), Decimal('-75'), True, True),
#  ('0R3SRPEYpqoUi3kq5ZsELw', Decimal('5.00'), 'SuVege', '615 S Trooper Rd', 'Audubon', 'PA', '19403', Decimal('40'), Decimal('-75'), False, True),
#  ('GUzVgl-dYDyvCULv2CrZEA', Decimal('3.17'), 'Aux Petits Delices', '162 E Lancaster Ave', 'Wayne', 'PA', '19087', Decimal('40'), Decimal('-75'), True, True),
#  ('UQNQzgy32KycsODdErBUpw', Decimal('1.50'), 'Flat Iron', '26 E Oregon Ave', 'Philadelphia', 'PA', '19148', Decimal('40'), Decimal('-75'), False, True),
#  ('My0ztUgvsTJhUhSBjI8F5g', Decimal('2.50'), "Giampino's Cucina Italiana B.Y.O.B", '1254 W Chester Pike', 'Havertown', 'PA', '19083', Decimal('40'), Decimal('-75'), True, True),
#  ('gJ5Szgefk1fJ4WSfGre_ng', Decimal('2.33'), 'Delta Sky Club', '8500 Essington Ave, Terminal D, Philadelphia International Airport', 'Philadelphia', 'PA', '19153', Decimal('40'), Decimal('-75'), True, False),
#  ('eWQt1GxjK0eQ9vzJkvpKxw', Decimal('4.67'), 'wok my way', '3000 Township Line Rd', 'Upper Darby', 'PA', '19026', Decimal('40'), Decimal('-75'), True, True),
#  ('Ki2BtVpfsuY07u7j-qtXbQ', Decimal('2.50'), 'Sticks & Stones', '1909 E Passyunk Ave', 'Philadelphia', 'PA', '19148', Decimal('40'), Decimal('-75'), False, True),
#  ('48hwr-F1xEFfHdTD1ueE2A', Decimal('2.83'), 'Starbucks', '337-341 South Broad St', 'Philadelphia', 'PA', '19107', Decimal('40'), Decimal('-75'), False, True),
#  ('PzqwENhkS_x5Czwn-dV6fQ', Decimal('4.67'), 'The Library Bar', '210 W Rittenhouse Sq', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), True, False),
#  ('elNr6gSmjopx96cylXVnVw', Decimal('3.63'), 'Lansdale Tavern', '839 W Main St', 'Lansdale', 'PA', '19446', Decimal('40'), Decimal('-75'), True, True),
#  ('xDFWKDY0sGyJYSMYc0uXWQ', Decimal('4.61'), "Eliyahu's Yardley Pizza", '20 S Main St', 'Yardley', 'PA', '19067', Decimal('40'), Decimal('-75'), True, True),
#  ('rpZrUHxtj5JZuq76FkbNdA', Decimal('3.78'), 'Mandarin Garden', '91 York Rd', 'Willow Grove', 'PA', '19090', Decimal('40'), Decimal('-75'), False, True),
#  ('Af0RbLKk4U-GU8J9OsRfyQ', Decimal('4.00'), 'Kimberton Whole Foods - Malvern', '429 E King Rd', 'Malvern', 'PA', '19355', Decimal('40'), Decimal('-76'), True, True),
#  ('n3sRn8jx0zT5ew4tjjrRBw', Decimal('3.67'), 'Spring Garden Restaurant', '400 Spring Garden St', 'Philadelphia', 'PA', '19123', Decimal('40'), Decimal('-75'), True, True),
#  ('xrlyoI0SHEFBJa52qQnPUw', Decimal('3.42'), 'iSushi', '425 S Broad St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), False, True),
#  ('DeSsx9UMrU3tfedZbZfCag', Decimal('5.00'), 'Veghada', '5912 Old York Rd', 'Philadelphia', 'PA', '19141', Decimal('40'), Decimal('-75'), True, True),
#  ('6glFzEDwOtT3MQRhtHIpTw', Decimal('4.17'), 'Blaze Pizza', '1100 W Montgomery Ave', 'Philadelphia', 'PA', '19122', Decimal('40'), Decimal('-75'), True, True),
#  ('5eldbLrF_oodWvu1VuEP8w', Decimal('2.29'), '1925 Cocktail Lounge', '111 S 17th St', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), False, False),
#  ('OXFCsM7_GkJ9KC93_UIbuw', Decimal('4.43'), 'PTG Catering', '6813 Ridge Ave', 'Philadelphia', 'PA', '19128', Decimal('40'), Decimal('-75'), True, True),
#  ('GsHtsymXIt9HYNjhfOcv_w', Decimal('3.30'), 'caribbean feast', '1338 Rising Ave', 'Phila', 'PA', '19140', Decimal('40'), Decimal('-75'), True, True),
#  ('vjO7cPDREXPjfozY0u2L_A', Decimal('1.43'), 'Chipotle Mexican Grill', '101 Turner Ln', 'West Chester', 'PA', '19380', Decimal('40'), Decimal('-76'), True, True),
#  ('0VYfnlvP5LsCEennaTYJkw', Decimal('4.60'), 'Newbolds Food & Libations', '211 York Rd', 'Jenkintown', 'PA', '19046', Decimal('40'), Decimal('-75'), True, True),
#  ('Q3ge5rGChoEbIjIUTk-qKw', Decimal('2.36'), 'QDOBA Mexican Eats', '261 Old York Rd, Ste 215A', 'Jenkintown', 'PA', '19046', Decimal('40'), Decimal('-75'), True, True),
#  ('KzSL2VzyT7bdHd0bhMyanw', Decimal('3.78'), 'Da Vinci Ristorante', '1533 S 11th St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), False, True),
#  ('ye_NPsD6rRX84zm1SkAO2A', Decimal('2.50'), 'Taco Bell', '2722 De Kalb Pike', 'Norristown', 'PA', '19401', Decimal('40'), Decimal('-75'), True, True),
#  ('IMJhGf4nyvrL58964xB54A', Decimal('5.00'), "Schenk's Family Bakery", '7951 Verree Rd', 'Philadelphia', 'PA', '19111', Decimal('40'), Decimal('-75'), True, True),
#  ('TyML9sqJmsHO0Mh3S1_f7A', Decimal('4.40'), "Klein's Supermarket", '2401 Pennsylvania Ave', 'Philadelphia', 'PA', '19130', Decimal('40'), Decimal('-75'), True, False),
#  ('a6nLdjFGoy3XmWhdtqBR3w', Decimal('2.50'), 'Cakes & Candies by Mary Ellen', '1332 B West Chester Pike', 'West Chester', 'PA', '19382', Decimal('40'), Decimal('-76'), True, False),
#  ('XGxsV7f16mW051jsEafAQQ', Decimal('4.50'), 'Fountain Restaurant', 'Four Seasons Hotel Philadelphia, 1 Logan Sq', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), False, False),
#  ('qh2xcM_-oY45dQjyiHP8MQ', Decimal('4.15'), "Donnie Mac's Deli on 4th", '326 Fayette St', 'Conshohocken', 'PA', '19428', Decimal('40'), Decimal('-75'), True, True),
#  ('Twy-1_FM5ROYMi_frf-ecQ', Decimal('2.77'), 'Thunderbird II Pizza', '188 Saxer Ave', 'Springfield', 'PA', '19064', Decimal('40'), Decimal('-75'), True, True),
#  ('l4YoHcvnsK7ICDrTqL7EEg', Decimal('4.38'), 'Vernick Fish', '1876 Arch St', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), True, True),
#  ('BFyfkA4u8tmSIvoZmEN00Q', Decimal('3.50'), 'Bentoulis Pizza', '1226 E Hunting Park Ave', 'Philadelphia', 'PA', '19124', Decimal('40'), Decimal('-75'), True, True),
#  ('T0FXx6p-ZemjHHsYtGh2qA', Decimal('3.57'), 'The Hearth', '7 E Ferry St', 'New Hope', 'PA', '18938', Decimal('40'), Decimal('-75'), False, True),
#  ('cWJ0UPiQZIYNCT-kPOWarA', Decimal('3.75'), 'California Tortilla', '284 Main St', 'Exton', 'PA', '19341', Decimal('40'), Decimal('-76'), True, True),
#  ('cm0bhBDPM3bjBefmEXa3BQ', Decimal('3.00'), "Nudy's Cafe - Chadds Ford", "240 Painters' Crossing", 'Chadds Ford', 'PA', '19317', Decimal('40'), Decimal('-76'), True, True),
#  ('tdWrPT2XT2NpPtfQQhf08w', Decimal('2.27'), 'Jasmine Asian House', '130 W Main St, Ste 120', 'Collegeville', 'PA', '19426', Decimal('40'), Decimal('-75'), True, True),
#  ('Z0U0sPwogMRdbhNZzx2wgw', Decimal('3.29'), 'The Boiling Pot', '319 Market St', 'Philadelphia', 'PA', '19106', Decimal('40'), Decimal('-75'), False, True),
#  ('Luc4Zxqua--lv9SLErxuWA', Decimal('4.20'), 'Raindrop Cafe', '1900 Market St', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), False, True),
#  ('yhMpYBlu_yimn9sT-cIayA', Decimal('4.60'), 'Fitz and Starts', '743 S 4th St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), True, True),
#  ('lynRxJIurnxYiaM-595Ngw', Decimal('3.75'), 'Fork & Bottle', '1 Liberty Blvd', 'Malvern', 'PA', '19355', Decimal('40'), Decimal('-76'), True, True),
#  ('yaAcSKptmJ7EHS04ohkguw', Decimal('4.25'), 'Chow284', '284 E Street Rd', 'Feasterville', 'PA', '19053', Decimal('40'), Decimal('-75'), False, True),
#  ('tJxrkonV5iuVZUNJev0jWA', Decimal('4.60'), 'Classic Cake Bakery & Cafe', '1617 John F Kennedy Blvd', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), False, True),
#  ('WdGDHENEKgw5j9jtfopF9w', Decimal('1.40'), 'Bella Napoli Pizzeria', '1065 Township Line Rd', 'Phoenixville', 'PA', '19460', Decimal('40'), Decimal('-76'), True, True),
#  ('fFFzotycO6ij8kAnmdzhJA', Decimal('4.29'), 'Cibo Italiano Ristorante', '914 Limekiln Pike', 'Maple Glen', 'PA', '19002', Decimal('40'), Decimal('-75'), False, True),
#  ('aHzZBvnqIQAzNb-MZ2K8AA', Decimal('3.00'), "Anthony's Wood Oven Pizzeria", '410 W Lincoln Hwy', 'Exton', 'PA', '19341', Decimal('40'), Decimal('-76'), True, True),
#  ('BtcOytu968lkyyO0IICv8w', Decimal('3.94'), 'Wissahickon Brewing Company', '3705 W Schoolhouse Ln', 'Philadelphia', 'PA', '19129', Decimal('40'), Decimal('-75'), True, True),
#  ('2z82YBsqTcf4VRkcdVCTmg', Decimal('4.00'), 'Panda Express', '942 Market Street', 'Philadelphia', 'PA', '19107', Decimal('40'), Decimal('-75'), True, True),
#  ('Nzxzawvzvt0Lq5J-PZMxVQ', Decimal('4.10'), 'The Pub by Wegmans', '1 Village Dr', 'King of Prussia', 'PA', '19406', Decimal('40'), Decimal('-75'), False, True),
#  ('WYYdQDjx-DsCanlP0DpImQ', Decimal('4.00'), 'J Sushi', '243 S 10th St', 'Philadelphia', 'PA', '19107', Decimal('40'), Decimal('-75'), False, True),
#  ('i6_elzfbdvp8rTjQ_AjY6A', Decimal('3.00'), 'IHOP', '130 W Lancaster Ave', 'Ardmore', 'PA', '19003', Decimal('40'), Decimal('-75'), True, True),
#  ('gBsPBsfVQj4NRfmlGlQSRQ', Decimal('4.25'), "Dominick's Pizzeria and Restaurant", '5780 Easton Rd', 'Plumsteadville', 'PA', '18902', Decimal('40'), Decimal('-75'), True, True),
#  ('fixjFaCYK2yDz5F-L2ASeg', Decimal('2.47'), 'Muscle Maker Grill', '2550 Grant Ave', 'Philadelphia', 'PA', '19114', Decimal('40'), Decimal('-75'), True, True),
#  ('apeTBNwOifm9Vj_v2SLqyg', Decimal('4.67'), 'Teng Da Asian Fusion', '721 Cheltena Ave', 'Jenkintown', 'PA', '19046', Decimal('40'), Decimal('-75'), True, True),
#  ('KnXWxp0DO4043CyWAnAx9g', Decimal('2.33'), 'Paddy Whacks Irish Sports Pub - Welsh Road', '9241-43 Roosevelt Blvd', 'Philadelphia', 'PA', '19114', Decimal('40'), Decimal('-75'), True, True),
#  ('lBZ0TUZu0S8_syGUTQs7Bg', Decimal('2.80'), "Dunkin'", '3907 Lincoln Highway', 'Downingtown', 'PA', '19335', Decimal('40'), Decimal('-76'), True, True),
#  ('mXCc-htrMH55gdaWF7wH2A', Decimal('3.76'), 'Lucky Star Asian Cuisine', '8919 Ridge Ave Store', 'Philadelphia', 'PA', '19128', Decimal('40'), Decimal('-75'), True, True),
#  ('oOKk4ZeB-wfwhZewXE4dQg', Decimal('3.00'), 'La Catrina', '13 W State St', 'Media', 'PA', '19063', Decimal('40'), Decimal('-75'), True, True),
#  ('MWmXGQ98KbRo3vsS5nZhMA', Decimal('4.33'), "Anthony's at Paxon Hollow", '850 Paxon Hollow Rd', 'Broomall', 'PA', '19008', Decimal('40'), Decimal('-75'), True, True),
#  ('Flj91i3ODKW-RDupjwWFqQ', Decimal('4.46'), 'Firebirds Wood Fired Grill', '1220 Bethlehem Pike', 'North Wales', 'PA', '19454', Decimal('40'), Decimal('-75'), True, True),
#  ('Cpl1-0iX6N7yauiJKhpXfA', Decimal('4.40'), 'Hong Kong Star Noodle House', '2852 Street Rd', 'Bensalem', 'PA', '19020', Decimal('40'), Decimal('-75'), True, True),
#  ('x1CtK2qnlCr_1DJFNo1_vw', Decimal('4.00'), 'El Limon - Norristown', '1000 Sandy Hill Rd', 'Norristown', 'PA', '19401', Decimal('40'), Decimal('-75'), True, True),
#  ('H34Zv7DSr9xmTfyDzAzHdA', Decimal('2.00'), 'AYA Kitchen', '2300 Lincoln Hwy, Suit 220A', 'Langhorne', 'PA', '19047', Decimal('40'), Decimal('-75'), False, True),
#  ('3lW1gubDMpnEIlo45eUKhA', Decimal('2.50'), 'Chipotle Mexican Grill', '620 W Dekalb Pike', 'King Of Prussia', 'PA', '19406', Decimal('40'), Decimal('-75'), True, True),
#  ('MCSyG3ndsNFJN-F9MQWM0A', Decimal('4.00'), 'The Foodery Chestnut Hill', '7829 Germantown Ave', 'Philadelphia', 'PA', '19118', Decimal('40'), Decimal('-75'), True, True),
#  ('0LXdnyZy4ae8J28Ckjvv7w', Decimal('3.86'), 'Sly Fox Taphouse at The Grove', '20 Liberty Blvd, Ste 100', 'Malvern', 'PA', '19355', Decimal('40'), Decimal('-76'), True, True),
#  ('9iBlpXwgBFLVnx6RmHsiCQ', Decimal('3.22'), 'Foods On First', '1429 Arch St', 'Philadelphia', 'PA', '19102', Decimal('40'), Decimal('-75'), True, True),
#  ('mNXeMZ2a3Y4paAUyZz2LIA', Decimal('3.75'), 'Whole Foods Market', '3737 W Chester Pike', 'Newtown Square', 'PA', '19073', Decimal('40'), Decimal('-75'), True, False),
#  ('DBV7IgOZrrSCzeyNOPN2Ew', Decimal('1.00'), 'Bonchon West Chester', '124 East Market St', 'West Chester', 'PA', '19382', Decimal('40'), Decimal('-76'), True, True),
#  ('fTc0orr5IcZMXUlH6iSmww', Decimal('1.80'), "Dunkin'", '750 Miles Rd', 'West Chester', 'PA', '19380', Decimal('40'), Decimal('-76'), True, True),
#  ('MOy8qGtBOoJzRnHnv3Y3JQ', Decimal('4.38'), 'Ants Pants on 4th', '526 S 4th St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), False, True),
#  ('nO5Y6duqIz37ffz48WZhtw', Decimal('3.67'), "Papa John's Pizza", '139 E. Dekalb Pike', 'King Of Prussia', 'PA', '19406', Decimal('40'), Decimal('-75'), True, True),
#  ('6KWj9Z00C4H63-8LdLkYvA', Decimal('1.17'), 'Pizza Hut', '1448 Bethlehem Pike', 'Flourtown', 'PA', '19031', Decimal('40'), Decimal('-75'), False, True),
#  ('VgFnAjjhK3AnV3u1-UVB2A', Decimal('3.60'), 'Fellini Cafe', '2 Waterview Rd', 'West Chester', 'PA', '19380', Decimal('40'), Decimal('-76'), True, True),
#  ('ab5hOCoFF0Jm4UvP6F5QwQ', Decimal('4.43'), 'Mipals Deli', '2300 S 16th St', 'Philadelphia', 'PA', '19145', Decimal('40'), Decimal('-75'), True, True),
#  ('cD0G9GY4Qz-KBZcbOBiYtw', Decimal('4.00'), 'ArdmoreQ', '64 Rittenhouse Pl', 'Ardmore', 'PA', '19003', Decimal('40'), Decimal('-75'), False, True),
#  ('hq0pGGIfaqBG36518UsWcw', Decimal('2.55'), 'ICandy', '254 S 12th St', 'Philadelphia', 'PA', '19107', Decimal('40'), Decimal('-75'), False, False),
#  ('2QMgg9WGNwmeLtMtC_R7iQ', Decimal('3.45'), 'Greenstraw', '243 N Sycamore St', 'Newtown', 'PA', '18940', Decimal('40'), Decimal('-75'), True, True),
#  ('tnq7b6ROl4RIyfQoxIrXhw', Decimal('2.24'), 'Chipotle Mexican Grill', '133 W Lancaster Ave', 'Ardmore', 'PA', '19003', Decimal('40'), Decimal('-75'), True, True),
#  ('dPI6efGzziUUOANACyMg6g', Decimal('4.14'), 'Zoes Kitchen', '920 Dekalb Pike, Ste 100', 'Blue Bell', 'PA', '19422', Decimal('40'), Decimal('-75'), False, True),
#  ('n7cTO0zm-Stm6p82NVM9Cw', Decimal('3.00'), 'Fuku', '313 Spring Garden St', 'Philadelphia', 'PA', '19123', Decimal('40'), Decimal('-75'), True, False),
#  ('CHg8ksvZJpDzd4s7Dc8EIQ', Decimal('4.00'), 'PrimoHoagies', '157 W Lancaster Ave', 'Ardmore', 'PA', '19003', Decimal('40'), Decimal('-75'), True, True),
#  ('3966MAWoL1GbB8Zjvspx1g', Decimal('3.33'), 'Urban Enoteca', '135 S 17th St, Latham Hotel Philadelphia', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), False, True),
#  ('LCxZ5RkXU9pQvKLInTLCrQ', Decimal('3.83'), "Car-Mira's Deli", '3240 Chichester Ave', 'Boothwyn', 'PA', '19061', Decimal('40'), Decimal('-75'), True, True),
#  ('tcDpEgmd14W4szC0DU3Pgg', Decimal('2.67'), 'Tropical Smoothie Cafe', '1600 N Broad St, Unit 4', 'Philadelphia', 'PA', '19121', Decimal('40'), Decimal('-75'), True, True),
#  ('GXJyNhIlZ0_Obeize1Oj7A', Decimal('3.90'), 'The Hadley', '2200 Benjamin Franklin Pkwy, E Tower', 'Philadelphia', 'PA', '19130', Decimal('40'), Decimal('-75'), True, True),
#  ('tKuWJvoaEfAJ-OevL5eMHw', Decimal('3.20'), 'PrimoHoagies', '345 Main St, Ste 7B', 'Harleysville', 'PA', '19438', Decimal('40'), Decimal('-75'), True, True),
#  ('5asvaAT-jDbOnCM3iPlScw', Decimal('4.77'), 'ReAnimator Coffee', '310 W Master St', 'Philadelphia', 'PA', '19122', Decimal('40'), Decimal('-75'), True, True),
#  ('ggX5HgWTcHBkMU37EgJLig', Decimal('4.00'), "Tony Luke's Beef and Beer Sports Bar", '26 E Oregon Ave', 'Philadelphia', 'PA', '19148', Decimal('40'), Decimal('-75'), False, True),
#  ('j-Akv5AL-z1vuM04oJRc8Q', Decimal('3.91'), 'Paradiso', '1627 E Passyunk Ave', 'Philadelphia', 'PA', '19148', Decimal('40'), Decimal('-75'), False, True),
#  ('dwkI0-b5PM2-yn-v7j2Agg', Decimal('4.88'), 'T cafe', '108 Chestnut St', 'Philadelphia', 'PA', '19106', Decimal('40'), Decimal('-75'), True, True),
#  ('vUc8E20T4d4HlHv2h2cyqg', Decimal('4.09'), 'The Upstairs Bar', '112 S 18th St', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), False, False),
#  ('tEiifAKuon_x00alBMmFcg', Decimal('2.33'), 'The Five Four Bar & Grill', '8919 New Falls Rd', 'Levittown', 'PA', '19054', Decimal('40'), Decimal('-75'), True, True),
#  ('8e1awFq00VzziCZzVLrDDg', Decimal('3.71'), 'Colonial Kitchen', '103 N Union Ave', 'Lansdowne', 'PA', '19050', Decimal('40'), Decimal('-75'), True, True),
#  ('6liIxwAycRwnzefTVqGGEw', Decimal('1.91'), 'Panera Bread', '3900 City Ave', 'Philadelphia', 'PA', '19131', Decimal('40'), Decimal('-75'), True, True),
#  ('oCoiJ-GBriiupCgpgWfVhQ', Decimal('4.33'), "Paddy's Old City Pub", '228 Race St', 'Philadelphia', 'PA', '19106', Decimal('40'), Decimal('-75'), True, False),
#  ('iuQlscgeor7lvRByKiaeiA', Decimal('3.78'), 'MidiCi The Neapolitan Pizza Company', '201 Main St, Ste 100', 'King of Prussia', 'PA', '19406', Decimal('40'), Decimal('-75'), False, True),
#  ('XX0xyWDpFc6Diq-XVHUckg', Decimal('3.44'), 'East Coast Wings & Grill', '2539 Castor Ave, Aramingo Super Ctr', 'Philadelphia', 'PA', '19134', Decimal('40'), Decimal('-75'), True, True),
#  ('Hihrbl62a7Y6I9ca0Jm1Uw', Decimal('4.17'), 'Stone Wok', '760 W St Rd', 'Warminster', 'PA', '18974', Decimal('40'), Decimal('-75'), True, True),
#  ('PTn0hZz7BiP5T2muyoxrjQ', Decimal('3.25'), 'Starbucks', '1301 Chestnut St', 'Philadelphia', 'PA', '19107', Decimal('40'), Decimal('-75'), True, True),
#  ('dX8dnwxVTpUvHXHlOXjgcw', Decimal('4.80'), 'Melange Tea & Spice', '1042 Pine St', 'Philadelphia', 'PA', '19107', Decimal('40'), Decimal('-75'), False, False),
#  ('p93DgPXIrrkVhCmp-BrNlg', Decimal('4.06'), 'Vgë Café', '845 B W Lancaster Ave', 'Bryn Mawr', 'PA', '19010', Decimal('40'), Decimal('-75'), False, True),
#  ('-kz82pLe268Cw59S6fD1BQ', Decimal('4.75'), "Arnold's Way", '319 W Main St', 'Lansdale', 'PA', '19446', Decimal('40'), Decimal('-75'), True, True),
#  ('t5n5IBvXYG55xXrq6hga3Q', Decimal('5.00'), 'Caffe Ida', '1732 W Passyunk Ave', 'Philadelphia', 'PA', '19145', Decimal('40'), Decimal('-75'), True, True),
#  ('IvyRHDj0cSRNFPjUK_BgKg', Decimal('3.86'), 'Cho Cho San Sushi Bar', '981 N Wales Rd', 'North Wales', 'PA', '19454', Decimal('40'), Decimal('-75'), True, True),
#  ('LNTg69EREH0vnMgh-lx8EQ', Decimal('2.00'), 'Pizza Hut', '240 S 69th St', 'Upper Darby', 'PA', '19082', Decimal('40'), Decimal('-75'), False, True),
#  ('UocjABfzi0iR671BQhsuSg', Decimal('4.20'), 'Wang House', '6649 Castor Ave', 'Philadelphia', 'PA', '19149', Decimal('40'), Decimal('-75'), False, True),
#  ('-N9ysCcO-ekOMlwidbn0FA', Decimal('3.50'), 'Panda Express', '3570 Horizon Blvd', 'Trevose', 'PA', '19053', Decimal('40'), Decimal('-75'), True, True),
#  ('FemC1HzXmvotxIxLZW06Cg', Decimal('2.33'), 'Rimedio', '4443 Spruce St', 'Philadelphia', 'PA', '19104', Decimal('40'), Decimal('-75'), False, False),
#  ('vZq8fdUEO-N2bCPOauj-lQ', Decimal('2.89'), 'Whole Foods Market', '175 N Pottstown Pike', 'Exton', 'PA', '19341', Decimal('40'), Decimal('-76'), True, True),
#  ('Us8A1l8qW5M4JOqyZ26x_g', Decimal('3.00'), 'China Garden Inn', '1007 Easton Rd', 'Willow Grove', 'PA', '19090', Decimal('40'), Decimal('-75'), True, True),
#  ('f5ZXsZQn6SFA1USdUYfdDw', Decimal('4.08'), 'Amis Trattoria', '138 W Lancaster Ave, Ste 140', 'Devon', 'PA', '19333', Decimal('40'), Decimal('-75'), True, True),
#  ('QNR-_GN_hg8YVCRq57xbJw', Decimal('2.60'), 'Broad Table Tavern', '12 S Chester Rd', 'Swarthmore', 'PA', '19081', Decimal('40'), Decimal('-75'), True, False),
#  ('UmVOfUFIiQjUNGHRkySaIA', Decimal('4.14'), 'Whole Foods Market', '475 Wilmington West Chester Pike', 'Glen Mills', 'PA', '19342', Decimal('40'), Decimal('-76'), True, True),
#  ('a-ouU5dKcMOYgOkftIX1YA', Decimal('2.50'), 'Starbucks', '1891 South State Rd', 'Upper Darby', 'PA', '19082', Decimal('40'), Decimal('-75'), True, True),
#  ('LYkQFSYLRVaRU4aL4KifSw', Decimal('3.75'), 'Candytopia - Philadelphia', '901 Market St, Ste 1150', 'Philadelphia', 'PA', '19107', Decimal('40'), Decimal('-75'), False, False),
#  ('j0nfkOogyh43lFcuUMlVsQ', Decimal('3.67'), "Stan's Deli", '3632 Powelton Ave', 'Philadelphia', 'PA', '19104', Decimal('40'), Decimal('-75'), False, True),
#  ('gO_W7JLMw2om3l1NUUlvjA', Decimal('3.91'), 'Gatehouse ', '4503 S Broad St', 'Philadelphia', 'PA', '19112', Decimal('40'), Decimal('-75'), True, True),
#  ('o6QW19rG1Xsy_ySsxqkpxg', Decimal('5.00'), 'Caffe Chicco', '2532 S Broad St', 'Philadelphia', 'PA', '19145', Decimal('40'), Decimal('-75'), True, True),
#  ('mhhCYSagskopFJNHlV5a9A', Decimal('3.38'), "Teddy's Pizza", '4748 Frankford Ave', 'Philadelphia', 'PA', '19124', Decimal('40'), Decimal('-75'), True, True),
#  ('r1g9VYLve8rfL3NUqA4uWw', Decimal('2.00'), 'Recess Lounge', '125 S 2nd St', 'Philadelphia', 'PA', '19106', Decimal('40'), Decimal('-75'), True, False),
#  ('G4y0HxePBgAYi3iJS_tUPQ', Decimal('4.75'), "Chickie's Italian Deli", '1014 Federal St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), False, True),
#  ('IiVvPH__XoTHRmWUAOFX-g', Decimal('4.00'), 'Smashburger', '4828 Edgmont Ave', 'Brookhaven', 'PA', '19015', Decimal('40'), Decimal('-75'), False, True),
#  ('8CMNPZyxkKSvcdw_QBp2EQ', Decimal('2.93'), 'Oakmont National Pub', '31 E Eagle Rd', 'Havertown', 'PA', '19083', Decimal('40'), Decimal('-75'), False, True),
#  ('yl8aBFKv-Yq-g14ZvE1FpA', Decimal('4.00'), 'Steak ’n Shake', '2530 W Main St', 'Norristown', 'PA', '19403', Decimal('40'), Decimal('-75'), False, False),
#  ('oXw9R3-fdgAzv0K6d35lkA', Decimal('4.33'), 'QU JAPAN BISTRO & BAR', '1635 Market St, Ste 103', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), True, True),
#  ('3rfFXpIQvFmYwtXj0aQ8nQ', Decimal('4.11'), 'Wasabi', '686 Downingtown Pike', 'West Chester', 'PA', '19380', Decimal('40'), Decimal('-76'), True, True),
#  ('sDi4t17ttgcIVZqd48EECA', Decimal('4.25'), 'Parliament', '30 S 15th St', 'Philadelphia', 'PA', '19102', Decimal('40'), Decimal('-75'), False, True),
#  ('nC0kethcH2AncAD2wHTRRA', Decimal('2.18'), 'Panera Bread', '151 E Swedesford Rd', 'Exton', 'PA', '19341', Decimal('40'), Decimal('-76'), True, True),
#  ('SbDETTgAgpIQ2NEmuRZmww', Decimal('1.88'), 'Chipotle Mexican Grill', '569 N Main St', 'Doylestown', 'PA', '18901', Decimal('40'), Decimal('-75'), True, True),
#  ('xdferXKwbgXAxbtmAShhAQ', Decimal('3.52'), 'Saxbys Rittenhouse', '2000 Walnut St', 'Philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), False, True),
#  ('OFtLsoXqrRgEqIZZxy5Hfw', Decimal('2.75'), 'The Fat Ham', '350 Mall Blvd', 'King of Prussia', 'PA', '19406', Decimal('40'), Decimal('-75'), False, True),
#  ('koor4lFTK3S5-igKGqHalQ', Decimal('3.50'), "Carmen's Italian Restaurant & Bar", '315 W MacDade Blvd', 'Folsom', 'PA', '19033', Decimal('40'), Decimal('-75'), True, True),
#  ('fGsEVei0W5kyhlL8TRNclg', Decimal('3.17'), 'Starbucks', '2 East Ridge Pike', 'Conshohocken', 'PA', '19428', Decimal('40'), Decimal('-75'), True, True),
#  ('OPb4w9WlyLlgUBadQl7P2A', Decimal('3.33'), "Ariana's Pizzeria & Italian Restaurant", '230 Levittown Pkwy', 'Levittown', 'PA', '19054', Decimal('40'), Decimal('-75'), True, True),
#  ('WIicEEmnWe10TYHajblM0Q', Decimal('5.00'), 'La Stalla Italian Market', '186 N Sycamore St', 'Newtown', 'PA', '18940', Decimal('40'), Decimal('-75'), True, True),
#  ('OYz76ipexaU20wuOuHQyBQ', Decimal('4.50'), 'Richman’s Ice Cream & Burger Co.', '379 Bustleton Pike', 'Feasterville-Trevose', 'PA', '19053', Decimal('40'), Decimal('-75'), True, False),
#  ('V_m4uwqWML3mxUbu1h_Mfw', Decimal('5.00'), "Crespo's Fratellis Pizzeria", '1253 Woodbourne Rd', 'Levittown', 'PA', '19057', Decimal('40'), Decimal('-75'), True, True),
#  ('UQLWfOGTF-7T2EQlUT92Zg', Decimal('4.60'), 'Lost Bread Co.', '1313 N Howard St', 'Philadelphia', 'PA', '19122', Decimal('40'), Decimal('-75'), True, True),
#  ('jmZt66lh8Lv70VoVwXgMow', Decimal('4.25'), 'Scooped Ice Cream & Gelato', '25 W State St', 'Media', 'PA', '19063', Decimal('40'), Decimal('-75'), True, True),
#  ('jyuy51CI4o4dZ9s3otZmWA', Decimal('4.75'), 'New Tiny Hoagie Shop', '122 Manchester Ave', 'Media', 'PA', '19063', Decimal('40'), Decimal('-75'), True, True),
#  ('mNRoB9WGd7NujbTsf0nOOA', Decimal('4.89'), 'Jules@Market', '111 Market St', 'Bristol', 'PA', '19007', Decimal('40'), Decimal('-75'), True, True),
#  ('_qvpjnhtIg7ClP_yiN6BpA', Decimal('3.36'), "Mark Anthony Paisano's Pizza & Catering", '105 W Eagle Rd', 'Havertown', 'PA', '19083', Decimal('40'), Decimal('-75'), True, True),
#  ('XXjHQ0CjzIqoZNyEC8lUmw', Decimal('3.89'), 'Sedona Taphouse', '44 W Gay St, Ste 1', 'West Chester', 'PA', '19380', Decimal('40'), Decimal('-76'), True, True),
#  ('iEu089Z_6Gkn9YAnGZw-kA', Decimal('3.40'), 'Ciao', '38 E Street Rd', 'West Chester', 'PA', '19382', Decimal('40'), Decimal('-76'), True, False),
#  ('I_wP6Zz_LMJXqiqTFo2eig', Decimal('3.33'), 'Five Guys', '4399 W Swamp Rd Cross Keys Plz', 'Doylestown', 'PA', '18901', Decimal('40'), Decimal('-75'), True, True),
#  ('2cfEAFZZee8fq3Xx6yZ87w', Decimal('4.00'), 'Starbucks', '3901 Walnut St', 'Philadelphia', 'PA', '19104', Decimal('40'), Decimal('-75'), True, True),
#  ('IS75-eprK9jQxoFsgQRkTw', Decimal('4.75'), 'Crust Pizzeria', '2415 W Darby Rd', 'Havertown', 'PA', '19083', Decimal('40'), Decimal('-75'), True, True),
#  ('TG8MSiFnoBRR-kglxMfm6g', Decimal('3.50'), "Argento's Pizza & Family Restaurant", '833 E Philadelphia Ave', 'Boyertown', 'PA', '19512', Decimal('40'), Decimal('-76'), True, True),
#  ('tMj79H5v1nOWmg9tsMfWiQ', Decimal('2.00'), "Dunkin'", '2951 Market St', 'Philadelphia', 'PA', '19104', Decimal('40'), Decimal('-75'), True, True),
#  ('SBgr-5n-kV3EeZztYsstUQ', Decimal('4.80'), 'Locust Lane Craft Brewery', '50 Three Tun Rd, Ste 4', 'Malvern', 'PA', '19355', Decimal('40'), Decimal('-76'), True, True),
#  ('xbsTbXKfuV8sIINTUQT0Dg', Decimal('3.56'), 'Tropical Smoothie Cafe', '251 E Swedesford Rd', 'Wayne', 'PA', '19087', Decimal('40'), Decimal('-75'), True, True),
#  ('ep_CRM3EQALDlEWURWc4rg', Decimal('4.83'), "Kaplan's New Model Bakery", '901 N 3rd St', 'Philadelphia', 'PA', '19123', Decimal('40'), Decimal('-75'), True, True),
#  ('EUlSBUUuaPVQ7NftUbyf8A', Decimal('2.50'), 'Charlies Country Ribs', '2528 W Diamond St', 'Philadelphia', 'PA', '19121', Decimal('40'), Decimal('-75'), True, True),
#  ('e4iAF4nM2I5CUulBm4OrSQ', Decimal('3.56'), "Bernie's Restaurant & Bar - University City", '3432 Sansom St', 'Philadelphia', 'PA', '19104', Decimal('40'), Decimal('-75'), False, True),
#  ('n4alafw1npRmVXzfBLUGPQ', Decimal('2.74'), "Nick's Roast Beef", '2210 Cottman Ave', 'Philadelphia', 'PA', '19149', Decimal('40'), Decimal('-75'), True, True),
#  ('Tz10h4z2J6j2V9gD2fgGKA', Decimal('3.86'), 'La Casa Di Lucias', '14425 Bustleton Ave', 'Philadelphia', 'PA', '19116', Decimal('40'), Decimal('-75'), True, True),
#  ('--epgcb7xHGuJ-4PUeSLAw', Decimal('4.33'), 'Manhattan Bagel', '200 York Road', 'Willow Grove', 'PA', '19090', Decimal('40'), Decimal('-75'), True, True),
#  ('hcP48OHgtr-YbdDiQ81qBg', Decimal('2.50'), 'Red Zone Old City', '35 S 2nd St', 'Philadelphia', 'PA', '19106', Decimal('40'), Decimal('-75'), False, True),
#  ('VPsiMIDsBsezca87SteVDA', Decimal('2.50'), 'Manhattan Bagel', '1345 W Chester Pike', 'Havertown', 'PA', '19083', Decimal('40'), Decimal('-75'), True, True),
#  ('bNSBYd-wASjWZ3hZWb0sGQ', Decimal('1.00'), 'The Juice Merchant', '920 Montgomery Ave', 'Narberth', 'PA', '19072', Decimal('40'), Decimal('-75'), False, True),
#  ('YSOEOmo2tvXZBNlclD9ERA', Decimal('2.33'), "Antonio's Brick Oven Pizza & Restaurant", '2447 Yellow Springs Rd', 'Malvern', 'PA', '19355', Decimal('40'), Decimal('-76'), True, True),
#  ('yYbKiItwE3eQIP_yI_26Ug', Decimal('1.80'), 'Toscana Gourmet Pizza', '825 W Sproul Rd', 'Springfield', 'PA', '19064', Decimal('40'), Decimal('-75'), True, True),
#  ('E6AnAHwEXEWwjbaRw5xyUg', Decimal('4.75'), 'Terrace Street Bakery & Cafe', '3862 Terrace St', 'Philadelphia', 'PA', '19128', Decimal('40'), Decimal('-75'), True, True),
#  ('mJbTRr_AJ8rDG78L8Min9w', Decimal('4.29'), 'White Horse Coffee & Creamery', '700 W Ave', 'Jenkintown', 'PA', '19046', Decimal('40'), Decimal('-75'), True, True),
#  ('2gFPQCmKKVi1aHgGTLRZvA', Decimal('3.75'), 'Green Eggs Cafe', '33 S 18th St', 'philadelphia', 'PA', '19103', Decimal('40'), Decimal('-75'), True, True),
#  ('ZRCY1Y3V4ikJs8K7yZ554A', Decimal('3.00'), "Manny Brown's", '512 South St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), False, True),
#  ('GRRMLWCU388_tfvpKYOM9w', Decimal('4.45'), 'Restaurant Neuf', '943 S 9th St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), False, False),
#  ('DTyeAYLV9YCc4mG5XTorTA', Decimal('2.50'), 'Starbucks', '3400 Civic Center Blvd', 'Philadelphia', 'PA', '19104', Decimal('40'), Decimal('-75'), True, True),
#  ('AJMH4STQfS9at_hU0PGQ7g', Decimal('4.59'), 'Forno Antico Pizza Napolitana', '416 E Main St', 'Collegeville', 'PA', '19426', Decimal('40'), Decimal('-75'), True, True),
#  ('LhgDTzrMSslaEuxUdVu7Kg', Decimal('3.40'), "Roy Tweedy's Old Fashioned Butcher Shop", '2042 Macdade Blvd', 'Holmes', 'PA', '19043', Decimal('40'), Decimal('-75'), True, True),
#  ('Oz7c0QA1C18Cb6tTdoehwQ', Decimal('4.10'), 'Gabi', '339 N Broad St', 'Philadelphia', 'PA', '19102', Decimal('40'), Decimal('-75'), True, True),
#  ('AJchGMnrpfIbTULXE2fasA', Decimal('3.00'), 'Baby Buns Philly', '111 S Independence Mall E', 'Philadelphia', 'PA', '19106', Decimal('40'), Decimal('-75'), True, True),
#  ('K0f_P7b6ADQagwunK6YcPg', Decimal('4.00'), 'City View Pizza', '1434 Cecil B Moore Ave', 'Philadelphia', 'PA', '19122', Decimal('40'), Decimal('-75'), True, True),
#  ('q1L8kFacrWVQwGyTsaGiuw', Decimal('3.78'), 'Maple Acre Farms', '2656 Narcissa Rd', 'Plymouth Meeting', 'PA', '19462', Decimal('40'), Decimal('-75'), True, True),
#  ('4qerWBd2zOalgPjAqsEwxw', Decimal('3.00'), "Mannino's Pizzaria & Italian Eatery", '903 N Charolette St', 'Pottstown', 'PA', '19464', Decimal('40'), Decimal('-76'), True, True),
#  ('VIbvORvfmyZETYQK_cn0SA', Decimal('1.33'), 'PrimoHoagies', '24 E Lancaster Ave', 'Downingtown', 'PA', '19335', Decimal('40'), Decimal('-76'), True, True),
#  ('OgRGre2aJ4BCXGtsaG4YRg', Decimal('3.91'), "Beverly's Pastry Shop", '322 E High St', 'Pottstown', 'PA', '19464', Decimal('40'), Decimal('-76'), True, True),
#  ('J5tO8SB3xmR7jqFW0slA_g', Decimal('2.00'), 'Iron Hill Brewery TapHouse', '260 Eagleview Blvd', 'Exton', 'PA', '19341', Decimal('40'), Decimal('-76'), True, False),
#  ('PON4EZK8TeqTi3CIuQbXpg', Decimal('4.42'), 'River Cat Cafe', '142 South Main St', 'New Hope', 'PA', '18938', Decimal('40'), Decimal('-75'), False, True),
#  ('GqPq9wiLefVLmUzVU-Nahw', Decimal('4.88'), 'The Carversville Kitchen', '6208 Fleecy Dale Rd', 'Carversville', 'PA', '18913', Decimal('40'), Decimal('-75'), False, True),
#  ('vpkCctZV4_q7iUkmtdZkzQ', Decimal('4.67'), 'Nothing Bundt Cakes', '2838 S Eagle Rd', 'Newtown', 'PA', '18940', Decimal('40'), Decimal('-75'), True, True),
#  ('VYEah7VF1EN13siPQPj4Tw', Decimal('4.90'), 'Éclat Chocolate', '24 S High St', 'West Chester', 'PA', '19382', Decimal('40'), Decimal('-76'), True, True),
#  ('JlCEOpvsyVfSn8BoHTmucw', Decimal('3.83'), 'Melt Shop', '2820 S Eagle Rd', 'Newtown', 'PA', '18940', Decimal('40'), Decimal('-75'), False, True),
#  ('CsSkl71x8DYLWaLcvwVRMA', Decimal('3.00'), 'PrimoHoagies', '1304 W Chester Pike', 'Havertown', 'PA', '19083', Decimal('40'), Decimal('-75'), True, True),
#  ('3S_g61xUct3Rmmx4rJS_mA', Decimal('2.35'), 'Smashburger', '8500 Essington Ave, Ste FH-7', 'Philadelphia', 'PA', '19153', Decimal('40'), Decimal('-75'), True, True),
#  ('yknD6Knbr_aw_9Co6zP8tQ', Decimal('4.38'), 'Burlap and Bean West End Roast House', '455 W Baltimore Ave', 'Media', 'PA', '19063', Decimal('40'), Decimal('-75'), True, True),
#  ('W5e4UAY9PoE3ydedIcc5GA', Decimal('4.80'), 'Dinics Pork & Beef', '1511 Kitty Hawk Ave', 'Philadelphia', 'PA', '19112', Decimal('40'), Decimal('-75'), True, True),
#  ('NaA1lTPxouNLq-zFI3IOYA', Decimal('3.30'), "Charlie Brown's Steakhouse", '1001 Baltimore Pike', 'Springfield', 'PA', '19064', Decimal('40'), Decimal('-75'), False, True),
#  ('2T4ZRPmweknjxdBfvHU3vg', Decimal('3.18'), "Lola's Garden", '51 St Georges Rd', 'Ardmore', 'PA', '19003', Decimal('40'), Decimal('-75'), True, True),
#  ('Ei0wJeADbNtwvA9CrvknJw', Decimal('5.00'), "Cocco's Gelateria", '550 S Oak Ave', 'Primos', 'PA', '19018', Decimal('40'), Decimal('-75'), True, True),
#  ('zGXgO4L7UdRB5Z1fzYWr7A', Decimal('1.33'), "Dunkin'", '1109 Bethlehem Pike', 'North Wales', 'PA', '19454', Decimal('40'), Decimal('-75'), True, True),
#  ('KdQmzwomvjLiMzD4UnLzBA', Decimal('5.00'), 'New Aston Palace', '3476 Concord Rd', 'Aston', 'PA', '19014', Decimal('40'), Decimal('-75'), True, True),
#  ('iD25g7vUG3asELjXtMGF9w', Decimal('3.42'), 'Taqueria del Sol', '4001 Welsh Rd', 'Willow Grove', 'PA', '19090', Decimal('40'), Decimal('-75'), False, True),
#  ('hFhkY65hFZD0oFZlR6l4EA', Decimal('3.00'), "Landolfi's Cafe & Deli", '40 S Main St', 'Yardley', 'PA', '19067', Decimal('40'), Decimal('-75'), True, True),
#  ('7vSahcMGVWAra7M1RkwH0Q', Decimal('4.00'), 'Big Boyz', '1940 Cottman Ave', 'Philadelphia', 'PA', '19111', Decimal('40'), Decimal('-75'), False, True),
#  ('V6nHZ__onRImXrX0u5Mu8w', Decimal('2.73'), "Philomena Santucci's Square Pizza", '4010 Cottman Ave', 'Philadelphia', 'PA', '19135', Decimal('40'), Decimal('-75'), True, True),
#  ('tz5rytGzU6DsZpHUxTRhUw', Decimal('3.33'), 'Milkboy', '401 South St', 'Philadelphia', 'PA', '19147', Decimal('40'), Decimal('-75'), True, True),
#  ('CAMIAMKJMaa9ivYyMsEcDw', None, "Bubby's Brisket & Bugsy's Weiners", '103 N 15th St', 'Philadelphia', 'PA', '19102', Decimal('40'), Decimal('-75'), True, True),
#  ('-nh_MbLmAURKEtHV4qpN3A', None, 'Lagos Island Pizza & Grille', '157 Long Ln', 'Kirklyn', 'PA', '19082', Decimal('40'), Decimal('-75'), True, True)]
